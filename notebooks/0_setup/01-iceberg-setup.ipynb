# %%
# pip로 간단 설치
import subprocess
import sys

# 필요한 패키지들 설치 (1-2분 소요)
packages = [
    "pyspark==3.4.0",
    "pyiceberg[pyarrow,duckdb]",
    "pandas",
    "matplotlib"
]

for package in packages:
    subprocess.check_call([sys.executable, "-m", "pip", "install", package])
    print(f"✅ {package} 설치 완료!")

print("🎉 모든 설치 완료!")
# Out:
# ✅ pyspark==3.4.0 설치 완료!
# ✅ pyiceberg[pyarrow,duckdb] 설치 완료!
# ✅ pandas 설치 완료!
# ✅ matplotlib 설치 완료!
# 🎉 모든 설치 완료!

# %%
# Iceberg JAR 파일 다운로드
import requests
import os

jar_url = "https://repo1.maven.org/maven2/org/apache/iceberg/iceberg-spark-runtime-3.4_2.12/1.4.3/iceberg-spark-runtime-3.4_2.12-1.4.3.jar"
jar_path = "/home/jovyan/iceberg-spark.jar"

print("📥 Iceberg JAR 다운로드 중...")
response = requests.get(jar_url)
with open(jar_path, 'wb') as f:
    f.write(response.content)

print(f"✅ JAR 다운로드 완료: {jar_path}")
print(f"📊 파일 크기: {os.path.getsize(jar_path) / 1024 / 1024:.1f} MB")
# Out:
# 📥 Iceberg JAR 다운로드 중...
# ✅ JAR 다운로드 완료: /home/jovyan/iceberg-spark.jar
# 📊 파일 크기: 28.0 MB
